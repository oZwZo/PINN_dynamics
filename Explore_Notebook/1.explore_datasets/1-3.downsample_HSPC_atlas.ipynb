# %%
import os, sys
import numpy as np
import pandas as pd
import scanpy as sc

# %%
# data_name = ckpt_path.split("/")[1].split("-")[0]
data_name = 'tom_pos'
adata = sc.read_h5ad(f"data/{data_name}.h5ad")

subset_cb = np.random.choice(adata.obs_names, int(0.1*len(adata.obs_names)), replace=False)
subset_ad = adata[subset_cb].copy()

# %%
subset_ad
# Out:
# AnnData object with n_obs × n_vars = 4939 × 4814
# ...
