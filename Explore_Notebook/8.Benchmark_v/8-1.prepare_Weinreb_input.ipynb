# %%
# %load_ext autoreload
# %autoreload 2
import os, sys, re
import numpy as np
import pandas as pd
import scanpy as sc
import torch
import time
import PINN

# %%
os.chdir("/ssd/users/Wergillius/Project/PINN_dynamics")

# %%
adata = sc.read_h5ad(f"data/klein_subset.h5ad")
cellstate_key = "DM_EigenVectors_multiscaled"
n_dimension = 5
base_cellstate = adata.obsm[cellstate_key][:,:n_dimension].copy()

# %%
base_cellstate = adata.obsm[cellstate_key][:,:n_dimension].copy()

# %%
adata.obs['timepoint_tx_days']
# Out:
# 0         6.0
# 1         6.0
# 2         6.0
# 4         6.0
# 6         6.0
#          ...
# 130875    6.0
# 130876    6.0
# 130877    6.0
# 130879    6.0
# 130883    6.0
# Name: timepoint_tx_days, Length: 47907, dtype: float64

# %%
adata.uns['pop']['t']
# Out:
# array([2, 4, 6])

# %%
CB_ay = [adata.obs.query("`timepoint_tx_days` == @t").index for t in adata.uns['pop']['t']]

# %%
DM_ay = [adata[cbs].obsm[cellstate_key] for cbs in CB_ay]
DM_ay = np.array([DM_ay], dtype='object')

DM_ay.shape
# Out:
# (1, 3)

# %%
np.save(f'data/TIGON_input/klein_subset_{cellstate_key}.npy', DM_ay, allow_pickle=True)
print('saved to ', f'data/TIGON_input/klein_subset_{cellstate_key}.npy')
# Out:
# 'data/TIGON_input/klein_subset_DM_EigenVectors_multiscaled.npy'

# %%
for ay in DM_ay[0]:
    print(ay.shape)
# Out:
# (4505, 5)
# (14675, 5)
# (28727, 5)

# %%
sc.pl.umap(adata, color='label_man')

# %% [markdown]
# # find full spectrum clone

# %%
clone_df = adata.obs[['Time_point','label_man','clones']]

# %%
clone_df
# Out:
#        Time_point               label_man      clones
# 0             6.0                  prog_2   Clone_573
# 1             6.0  prog_Baso_Meg_Ery_Mast  Clone_1440
# 2             6.0               prog_Mono   Clone_394
# 4             6.0            prog_Meg_Ery  Clone_1972
# 6             6.0                prog_Neu  Clone_1450
# ...           ...                     ...         ...
# 130875        6.0            prog_Meg_Ery    Clone_12
# 130876        6.0                  prog_2   Clone_267
# 130877        6.0          early_prog_Neu  Clone_3534
# 130879        6.0               prog_Mono  Clone_4945
# 130883        6.0                  prog_2  Clone_1374
#
# [47907 rows x 3 columns]

# %%
clone_by_time = clone_df.groupby("clones").agg({"Time_point":"nunique"}).reset_index()
all_in_clones = clone_by_time.query('`Time_point` == 3').clones.values
clone_by_time.query('`Time_point` == 3')
# Out:
#           clones  Time_point
# 10      Clone_10           3
# 15      Clone_15           3
# 21      Clone_21           3
# 38      Clone_38           3
# 44      Clone_44           3
# ...          ...         ...
# 5809  Clone_5817           3
# 5810  Clone_5818           3
# 5824  Clone_5832           3
# 5825  Clone_5833           3
# 5842  Clone_5850           3
#
# [923 rows x 2 columns]

# %%
clone_count = clone_df.query("`clones` in @all_in_clones")['clones'].value_counts()

# %%
candidate = clone_count[clone_count > 50].index.to_list()

# %%
def compute_proportion_bytime(clone_df):
    df = []
    for t in clone_df.Time_point.unique():
        series = clone_df.query("`Time_point` == @t").groupby("label_man").agg({'clones':'count'})['clones']
        total_cellcount = series.sum()
        series = series/total_cellcount
        df.append(series)

    proportion = pd.concat(df,axis=1)
    proportion.columns = ['p_Day%s'%t for t in clone_df.Time_point.unique()]

    return proportion

# %%
proportion_all = compute_proportion_bytime(clone_df)
proportion_all.head()
# Out:
#            p_Day6.0  p_Day4.0  p_Day2.0
# label_man
# Baso       0.115223  0.060511  0.000666
# DC         0.001497  0.001295  0.001554
# Eos        0.005256  0.002726  0.000000
# Ery        0.009712  0.004838  0.002664
# Ly         0.003063  0.006882  0.003108

# %%
from scipy.special import kl_div

def compute_kld(proportion_df1, proportion_df2):
    assert proportion_df1.shape == proportion_df2.shape

    p1 = proportion_df1.values + 1e-8
    p2 = proportion_df2.values + 1e-8

    kld = []
    for i in range(3):
        kld.append(kl_div(p1[:,i], p2[:,i]).sum())
    return kld

# %%
clone_kld = []
for clone in candidate:
    clone_p  = compute_proportion_bytime(clone_df.query("`clones` == @clone"))
    clone_kld.append(compute_kld(proportion_all, clone_p))

# %%
np.array(clone_kld) #[6]
# Out:
# array([[ 8.75474224,  8.59477355,  9.61221217],
#        [ 9.96966176,  9.84416678,  8.6940778 ],
#        [ 8.16141067,  6.45410784,  9.61221217],
#        [ 7.02400294,  7.35435154, 13.99964623],
#        [12.44201166, 13.3034478 , 14.24277433],
#        [ 8.45803024,  6.44892332,  9.61221217],
#        [ 6.98149309,  7.99329971,  9.61221217],
#        [ 6.61647319,  9.76970134,  9.61221217],
#        [ 9.68348637, 13.3034478 , 15.58893057],
#        [ 9.49374549,  8.73814008,  9.61221217],
#        [ 6.84220967, 13.3034478 , 15.46742908],
#        [ 8.21385372,  9.2048009 ,  9.61221217],
#        [ 5.76141352,  6.83662042, 13.99964623],
#        [12.62350785, 12.77241184,  9.61221217],
#        [ 8.1665906 , 14.77459178,  7.74647647],
#        [ 7.90451971,  8.0489675 , 13.45990597],
#        [ 8.07495775,  5.70630374, 13.99964623],
#        [10.23048475,  7.820146  ,  9.61221217],
#        [10.88663523,  7.2023276 ,  9.61221217],
#        [12.40037091, 13.3034478 , 15.49228454],
#        [ 9.62200664, 13.3034478 , 15.87543137],
#        [ 9.78977141,  9.35780661, 13.99964623],
#        [12.38741826,  9.86910608,  9.61221217],
#        [11.25583264, 13.24319617,  9.61221217],
#        [10.73994726,  6.68895387,  9.61221217],
#        [ 8.48993805, 13.3034478 , 16.28169793],
#        [11.94091369, 13.3034478 , 15.88446655]])

# %%
print(candidate[6], candidate[2])
# Out:
# Clone_67 Clone_3345

# %%
for clone in candidate[:10]:
    cbs = [adata.obs.query("`timepoint_tx_days` == @t & `clones` == @clone").index.to_list()
            for t in adata.uns['pop']['t']]

    all_cbs = []
    for cb in cbs:
        all_cbs += cb

    sc.pl.umap(adata[all_cbs], color=['Time_point'], title=clone)

# %%
['Clone_3869' , 'Clone_2673' , 'Clone_2831']

# %%
for MC in range(1,13):
    MC = str(MC)
    cbs = [adata.obs.query("`timepoint_tx_days` == @t & `Meta clones` == @MC").index.to_list()
            for t in adata.uns['pop']['t']]

    all_cbs = []
    for cb in cbs:
        all_cbs += cb

    sc.pl.umap(adata[all_cbs], color=['Time_point'], title=MC, figsize=(3,3))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 10
#       7 for cb in cbs:
#       8     all_cbs += cb
# ---> 10 sc.pl.umap(adata[all_cbs], color=['Time_point'], title=MC, figsize=(3,3))
#
# File /ssd/users/Wergillius/miniforge3/envs/PINN_torch/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:691, in umap(adata, **kwargs)
#     632 @_wraps_plot_scatter
#     633 @_doc_params(
#     634     adata_color_etc=doc_adata_color_etc,
#    (...)
#     638 )
#     639 def umap(adata: AnnData, **kwargs) -> Figure | Axes | list[Axes] | None:
#     640     """\
#     641     Scatter plot in UMAP basis.
#     642
#    (...)
#     689     tl.umap
#     690     """
# --> 691     return embedding(adata, "umap", **kwargs)
#
# File /ssd/users/Wergillius/miniforge3/envs/PINN_torch/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:407, in embedding(adata, basis, color, mask_obs, gene_symbols, use_raw, sort_order, edges, edges_width, edges_color, neighbors_key, arrows, arrows_kwds, groups, components, dimensions, layer, projection, scale_factor, color_map, cmap, palette, na_color, na_in_legend, size, frameon, legend_fontsize, legend_fontweight, legend_loc, legend_fontoutline, colorbar_loc, vmax, vmin, vcenter, norm, add_outline, outline_width, outline_color, ncols, hspace, wspace, title, show, save, ax, return_fig, marker, **kwargs)
#     396         for s, c in [(bg_size, bg_color), (gap_size, gap_color)]:
#     397             ax.scatter(
#     398                 coords[:, 0],
#     399                 coords[:, 1],
#    (...)
#     404                 **kwargs_outline,
#     405             )
# --> 407     cax = scatter(
#     408         coords[:, 0],
#     409         coords[:, 1],
#     410         c=color_vector,
#     411         rasterized=settings._vector_friendly,
#     412         marker=marker[count],
#     413         **kwargs_scatter,
#     414     )
#     416 # remove y and x ticks
#     417 ax.set_yticks([])
#
# File /ssd/users/Wergillius/miniforge3/envs/PINN_torch/lib/python3.9/site-packages/matplotlib/__init__.py:1446, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1443 @functools.wraps(func)
#    1444 def inner(ax, *args, data=None, **kwargs):
#    1445     if data is None:
# -> 1446         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448     bound = new_sig.bind(ax, *args, **kwargs)
#    1449     auto_label = (bound.arguments.get(label_namer)
#    1450                   or bound.kwargs.get(label_namer))
#
# File /ssd/users/Wergillius/miniforge3/envs/PINN_torch/lib/python3.9/site-packages/matplotlib/axes/_axes.py:4692, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4688         keys_str = ", ".join(f"'{k}'" for k in extra_keys)
#    4689         _api.warn_external(
#    4690             "No data for colormapping provided via 'c'. "
#    4691             f"Parameters {keys_str} will be ignored")
# -> 4692 collection._internal_update(kwargs)
#    4694 # Classic mode only:
#    4695 # ensure there are margins to allow for the
#    4696 # finite size of the symbols.  In v2.x, margins
#    4697 # are present by default, so we disable this
#    4698 # scatter-specific override.
#    4699 if mpl.rcParams['_internal.classic_mode']:
#
# File /ssd/users/Wergillius/miniforge3/envs/PINN_torch/lib/python3.9/site-packages/matplotlib/artist.py:1223, in Artist._internal_update(self, kwargs)
#    1216 def _internal_update(self, kwargs):
#    1217     """
#    1218     Update artist properties without prenormalizing them, but generating
#    1219     errors as if calling `set`.
#    1220
#    1221     The lack of prenormalization is to maintain backcompatibility.
#    1222     """
# -> 1223     return self._update_props(
#    1224         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1225         "{prop_name!r}")
#
# File /ssd/users/Wergillius/miniforge3/envs/PINN_torch/lib/python3.9/site-packages/matplotlib/artist.py:1197, in Artist._update_props(self, props, errfmt)
#    1195             func = getattr(self, f"set_{k}", None)
#    1196             if not callable(func):
# -> 1197                 raise AttributeError(
#    1198                     errfmt.format(cls=type(self), prop_name=k))
#    1199             ret.append(func(v))
#    1200 if ret:
#
# AttributeError: PathCollection.set() got an unexpected keyword argument 'figsize'

# %%
cbs = [adata.obs.query("`timepoint_tx_days` == @t & `clones` == 'Clone_67'").index.to_list()
        for t in adata.uns['pop']['t']]

all_cbs = []
for cb in cbs:
    all_cbs += cb

sc.pl.umap(adata[all_cbs], color=['Time_point', 'label_man'])

# %%
adata.obs['Meta clones']
# Out:
# 0         8
# 1         8
# 2         0
# 4         4
# 6         3
#          ..
# 130875    4
# 130876    8
# 130877    1
# 130879    0
# 130883    5
# Name: Meta clones, Length: 47907, dtype: category
# Categories (14, object): ['0', '1', '2', '3', ..., '10', '11', '12', '-1.0']

# %%
sc.pl.umap(adata[adata.obs.query("`clones` == 'Clone_67'").index], color='label_man')
